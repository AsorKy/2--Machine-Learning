# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([[3,2],
              [4,1]])

X = np.array([[3,4],
              [3,2]])

eisys = np.linalg.eig(X)

print(eisys)
# Out:
# (array([ 6., -1.]), array([[ 0.8       , -0.70710678],
#        [ 0.6       ,  0.70710678]]))

# %%
print(np.linalg.eig(X))
# Out:
# (array([ 5., -1.]), array([[ 0.70710678, -0.4472136 ],
#        [ 0.70710678,  0.89442719]]))

# %%
eigenvalues, eigenvectors = np.linalg.eig(X)
print(eigenvalues)
print(eigenvectors)
# Out:
# [ 5. -1.]
# [[ 0.70710678 -0.4472136 ]
#  [ 0.70710678  0.89442719]]

# %%
v_np = eigenvectors[:,1]
print(eigenvectors[:,0])
print(eigenvectors[:,1])
# Out:
# [0.70710678 0.70710678]
# [-0.4472136   0.89442719]

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/2)-Machine Learning/1)-Platzy Career (Machine Learning)/3)-Applied Linear Algebra for ML/0)-Auxiliar_Functions/graficarVectores.ipynb"

# %%
v = np.array([[-1],[2]])
u = X.dot(v)
print(u)
# Out:
# [[ 1]
#  [-2]]

# %%
graficarVectores([u.flatten(),v.flatten(),v_np.flatten()],
                 cols = ['green','orange','blue'])
plt.xlim(-3,2)
plt.ylim(-4,3)
# Out:
# (-4.0, 3.0)
