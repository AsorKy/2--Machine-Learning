# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/2)-Machine Learning/1)-Platzy Career (Machine Learning)/3)-Applied Linear Algebra for ML/0)-Auxiliar_Functions/graficarVectores.ipynb"

# %%
orange_light = '#FFA913'
blue_light = '#1190FF'

# %%
X = np.array([[3,2],
              [4,1]])
print(X)
# Out:
# [[3 2]
#  [4 1]]

# %%
v = np.array([[1],
              [1]])
print(v)
# Out:
# [[1]
#  [1]]

# %%
u = X.dot(v)
print(u)
# Out:
# [[5]
#  [5]]

# %%
graficarVectores([u.flatten(),v.flatten()],
                 cols = [orange_light, blue_light])
plt.xlim(-1,6)
plt.ylim(-1,6)
# Out:
# (-1.0, 6.0)

# %%
lambda_1 = 5
lambda_1*v
# Out:
# array([[5],
#        [5]])

# %%
s = np.array([[-1],
              [2]])
print(s)
# Out:
# [[-1]
#  [ 2]]

# %%
t = X.dot(s)
print(t)
# Out:
# [[ 1]
#  [-2]]

# %%
graficarVectores([s.flatten(),t.flatten()],
                 cols = [orange_light, blue_light])
plt.xlim(-3,3)
plt.ylim(-3,3)
# Out:
# (-3.0, 3.0)
